# %% [markdown]
# # Demo 01 -  Sakila Star Schema & ETL
#
# All the database tables in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://video.udacity-data.com/topher/2021/August/61120e06_pagila-3nf/pagila-3nf.png)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](https://video.udacity-data.com/topher/2021/August/61120d38_pagila-star/pagila-star.png)

# %% [markdown]
# # STEP0: Using ipython-sql
#
# - load ipython-sql: `%load_ext sql`
#
# - To execute SQL queries you write one of the following atop of your cell:
#     - `%sql`
#         - For a one-liner SQL query
#         - You can access a python var using `$`
#     - `%%sql`
#         - For a multi-line SQL query
#         - You can **NOT** access a python var using `$`
#
#
# - Running a connection string like:
# `postgresql://postgres:postgres@db:5432/pagila` connects to the database

# %% [markdown]
# # STEP1 : Connect to the local database where Pagila is loaded

# %% [markdown]
# ##  1.1 Create the pagila db and fill it with data
# - Adding `"!"` at the beginning of a jupyter cell runs a command in a shell, i.e. we are not running python code but we are running the `createdb` and `psql` postgresql commmand-line utilities

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-schema.sql
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-data.sql
# Out:
#  setval
# --------
#     200
# (1 row)
#
#  setval
# --------
#     605
# (1 row)
#
#  setval
# --------
#      16
# (1 row)
#
#  setval
# --------
#     600
# (1 row)
#
#  setval
# --------
#     109
# (1 row)
#
#  setval
# --------
#     599
# (1 row)
#
#  setval
# --------
#    1000
# (1 row)
#
#  setval
# --------
#    4581
# (1 row)
#
#  setval
# --------
#       6
# (1 row)
#
#  setval
# --------
#   32098
# (1 row)
#
#  setval
# --------
#   16049
# (1 row)
#
#  setval
# --------
#       2
# (1 row)
#
#  setval
# --------
#       2
# (1 row)

# %% [markdown]
# ## 1.2 Connect to the newly created db

# %%
# %load_ext sql

# %%
DB_ENDPOINT = "127.0.0.1"
DB = 'pagila'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila

# %%
# %sql $conn_string
# Out:
# 'Connected: student@pagila'

# %% [markdown]
# # STEP 1.1: Create and populate the star schema

# %% [markdown]
# # STEP2 : Explore the  3NF Schema

# %% [markdown]
# <img src="../images/7_pagila-3nf.png" width="60%"/>

# %% [markdown]
# ## 2.1 How much? What data sizes are we looking at?

# %%
nStores = %sql select count(*) from store;
nFilms = %sql select count(*) from film;
nCustomers = %sql select count(*) from customer;
nRentals = %sql select count(*) from rental;
nPayment = %sql select count(*) from payment;
nStaff = %sql select count(*) from staff;
nCity = %sql select count(*) from city;
nCountry = %sql select count(*) from country;

print("nFilms\t\t=", nFilms[0][0])
print("nCustomers\t=", nCustomers[0][0])
print("nRentals\t=", nRentals[0][0])
print("nPayment\t=", nPayment[0][0])
print("nStaff\t\t=", nStaff[0][0])
print("nStores\t\t=", nStores[0][0])
print("nCities\t\t=", nCity[0][0])
print("nCountry\t\t=", nCountry[0][0])
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
# nFilms		= 1000
# nCustomers	= 599
# nRentals	= 16044
# nPayment	= 16049
# nStaff		= 2
# nStores		= 2
# nCities		= 600
# nCountry		= 109

# %% [markdown]
# ## 2.2 When? What time period are we talking about?

# %%
# %%sql
# select min(payment_date) as start, max(payment_date) as end from payment;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
# [(datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), datetime.datetime(2017, 5, 14, 13, 44, 29, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ## 2.3 Where? Where do events in this database occur?

# %%
# %%sql
# select district,  sum(city_id) as n
# from address
# group by district
# order by n desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Shandong', 3237),
#  ('England', 2974),
#  ('So Paulo', 2952),
#  ('West Bengali', 2623),
#  ('Buenos Aires', 2572),
#  ('Uttar Pradesh', 2462),
#  ('California', 2444),
#  ('Southern Tagalog', 1931),
#  ('Tamil Nadu', 1807),
#  ('Hubei', 1790)]

# %% [markdown]
# # STEP3: Perform some simple data analysis

# %% [markdown]
# ## 3.1 Insight 1:   Top Grossing Movies
# - Payments amounts are in table `payment`
# - Movies are in table `film`
# - They are not directly linked, `payment` refers to a `rental`, `rental` refers to an `inventory` item and `inventory` item refers to a `film`
# - `payment` &rarr; `rental` &rarr; `inventory` &rarr; `film`

# %% [markdown]
# ### 3.1.1 Films

# %%
# %%sql
# select film_id, title, release_year, rental_rate, rating  from film limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 'ACADEMY DINOSAUR', 2006, Decimal('0.99'), 'PG'),
#  (2, 'ACE GOLDFINGER', 2006, Decimal('4.99'), 'G'),
#  (3, 'ADAPTATION HOLES', 2006, Decimal('2.99'), 'NC-17'),
#  (4, 'AFFAIR PREJUDICE', 2006, Decimal('2.99'), 'G'),
#  (5, 'AFRICAN EGG', 2006, Decimal('2.99'), 'G')]

# %% [markdown]
# ### 3.1.2 Payments

# %%
# %%sql
# select * from payment limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(16050, 269, 2, 7, Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16051, 269, 1, 98, Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16052, 269, 2, 678, Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16053, 269, 2, 703, Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16054, 269, 1, 750, Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ### 3.1.3 Inventory

# %%
# %%sql
# select * from inventory limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (2, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (3, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (4, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (5, 1, 2, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ### 3.1.4 Get the movie of every payment

# %%
# %%sql
# SELECT f.title, p.amount, p.payment_date, p.customer_id
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [('SWARM GOLD', Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('PACKER MADIGAN', Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('SOMETHING DUCK', Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('DRACULA CRYSTAL', Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('CLOSER BANG', Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269)]

# %% [markdown]
# ### 3.1.5 sum movie rental revenue

# %%
# %%sql
# SELECT f.title, sum(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# GROUP BY title
# ORDER BY revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('TELEGRAPH VOYAGE', Decimal('231.73')),
#  ('WIFE TURN', Decimal('223.69')),
#  ('ZORRO ARK', Decimal('214.69')),
#  ('GOODFELLAS SALUTE', Decimal('209.69')),
#  ('SATURDAY LAMBS', Decimal('204.72')),
#  ('TITANS JERK', Decimal('201.71')),
#  ('TORQUE BOUND', Decimal('198.72')),
#  ('HARRY IDAHO', Decimal('195.70')),
#  ('INNOCENT USUAL', Decimal('191.74')),
#  ('HUSTLER PARTY', Decimal('190.78'))]

# %% [markdown]
# ## 3.2 Insight 2:   Top grossing cities
# - Payments amounts are in table `payment`
# - Cities are in table `cities`
# - `payment` &rarr; `customer` &rarr; `address` &rarr; `city`

# %% [markdown]
# ### 3.2.1 Get the city of each payment

# %%
# %%sql
# SELECT p.customer_id, p.rental_id, p.amount, ci.city
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.payment_date
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [(130, 1, Decimal('2.99'), 'guas Lindas de Gois'),
#  (459, 2, Decimal('2.99'), 'Qomsheh'),
#  (408, 3, Decimal('3.99'), 'Jaffna'),
#  (333, 4, Decimal('4.99'), 'Baku'),
#  (222, 5, Decimal('6.99'), 'Jaroslavl'),
#  (549, 6, Decimal('0.99'), 'Santiago de Compostela'),
#  (269, 7, Decimal('1.99'), 'Salinas'),
#  (239, 8, Decimal('4.99'), 'Ciomas'),
#  (126, 9, Decimal('4.99'), 'Po'),
#  (399, 10, Decimal('5.99'), 'Okara')]

# %% [markdown]
# ### 3.2.2 Top grossing cities

# %%
# %%sql
# SELECT ci.city ,  sum(p.amount) as revenue
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# group by ci.city
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Cape Coral', Decimal('221.55')),
#  ('Saint-Denis', Decimal('216.54')),
#  ('Aurora', Decimal('198.50')),
#  ('Molodetno', Decimal('195.58')),
#  ('Apeldoorn', Decimal('194.61')),
#  ('Santa Brbara dOeste', Decimal('194.61')),
#  ('Qomsheh', Decimal('186.62')),
#  ('London', Decimal('180.52')),
#  ('Ourense (Orense)', Decimal('177.60')),
#  ('Bijapur', Decimal('175.61'))]

# %% [markdown]
# ## 3.3 Insight 3 : Revenue of a movie by customer city and by month

# %% [markdown]
# ### 3.3.1 Total revenue by month

# %%
# %%sql
# SELECT sum(p.amount) as revenue, EXTRACT(month FROM p.payment_date) as month
# from payment p
# group by month
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(Decimal('28559.46'), 4.0),
#  (Decimal('23886.56'), 3.0),
#  (Decimal('9631.88'), 2.0),
#  (Decimal('4824.43'), 1.0),
#  (Decimal('514.18'), 5.0)]

# %% [markdown]
# ### 3.3.2 Each movie by customer city and by month (data cube)

# %%
# %%sql
# SELECT f.title, p.amount, p.customer_id, ci.city, p.payment_date,EXTRACT(month FROM p.payment_date) as month
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.payment_date
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('BLANKET BEVERLY', Decimal('2.99'), 130, 'guas Lindas de Gois', datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('FREAKY POCUS', Decimal('2.99'), 459, 'Qomsheh', datetime.datetime(2017, 1, 24, 21, 22, 59, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('GRADUATE LORD', Decimal('3.99'), 408, 'Jaffna', datetime.datetime(2017, 1, 24, 21, 32, 5, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('LOVE SUICIDES', Decimal('4.99'), 333, 'Baku', datetime.datetime(2017, 1, 24, 21, 33, 7, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('IDOLS SNATCHERS', Decimal('6.99'), 222, 'Jaroslavl', datetime.datetime(2017, 1, 24, 21, 33, 47, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('MYSTIC TRUMAN', Decimal('0.99'), 549, 'Santiago de Compostela', datetime.datetime(2017, 1, 24, 21, 36, 33, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('SWARM GOLD', Decimal('1.99'), 269, 'Salinas', datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('LAWLESS VISION', Decimal('4.99'), 239, 'Ciomas', datetime.datetime(2017, 1, 24, 22, 0, 12, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('MATRIX SNOWMAN', Decimal('4.99'), 126, 'Po', datetime.datetime(2017, 1, 24, 22, 29, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('HANGING DEEP', Decimal('5.99'), 399, 'Okara', datetime.datetime(2017, 1, 24, 22, 30, 47, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0)]

# %% [markdown]
# ### 3.3.3 Sum of revenue of each movie by customer city and by month

# %%
# %%sql
# SELECT f.title, ci.city,EXTRACT(month FROM p.payment_date) as month, sum(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# group by (f.title, ci.city, month)
# order by month, revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('SHOW LORD', 'Mannheim', 1.0, Decimal('11.99')),
#  ('KISSING DOLLS', 'Toulon', 1.0, Decimal('10.99')),
#  ('CASUALTIES ENCINO', 'Warren', 1.0, Decimal('10.99')),
#  ('TELEGRAPH VOYAGE', 'Naala-Porto', 1.0, Decimal('10.99')),
#  ('AMERICAN CIRCUS', 'Callao', 1.0, Decimal('10.99')),
#  ('CALIFORNIA BIRDS', 'Plock', 1.0, Decimal('9.99')),
#  ('AUTUMN CROW', 'Ashgabat', 1.0, Decimal('9.99')),
#  ('DAY UNFAITHFUL', 'Baybay', 1.0, Decimal('9.99')),
#  ('DARKO DORADO', 'Bhilwara', 1.0, Decimal('9.99')),
#  ('HEAD STRANGER', 'Xiangtan', 1.0, Decimal('9.99'))]

# %% [markdown]
# # STEP 4 : Creating Facts & Dimensions

# %% [markdown]
# <img src="../images/6-pagila_star_schema.png" width="60%"/>

# %%
# %%sql
# CREATE TABLE dimDate
# (
#   date_key integer NOT NULL PRIMARY KEY,
#   date date NOT NULL,
#   year smallint NOT NULL,
#   quarter smallint NOT NULL,
#   month smallint NOT NULL,
#   day smallint NOT NULL,
#   week smallint NOT NULL,
#   is_weekend boolean
# );
#
# CREATE TABLE dimCustomer
# (
#   customer_key SERIAL PRIMARY KEY,
#   customer_id  smallint NOT NULL,
#   first_name   varchar(45) NOT NULL,
#   last_name    varchar(45) NOT NULL,
#   email        varchar(50),
#   address      varchar(50) NOT NULL,
#   address2     varchar(50),
#   district     varchar(20) NOT NULL,
#   city         varchar(50) NOT NULL,
#   country      varchar(50) NOT NULL,
#   postal_code  varchar(10),
#   phone        varchar(20) NOT NULL,
#   active       smallint NOT NULL,
#   create_date  timestamp NOT NULL,
#   start_date   date NOT NULL,
#   end_date     date NOT NULL
# );
#
# CREATE TABLE dimMovie
# (
#   movie_key          SERIAL PRIMARY KEY,
#   film_id            smallint NOT NULL,
#   title              varchar(255) NOT NULL,
#   description        text,
#   release_year       year,
#   language           varchar(20) NOT NULL,
#   original_language  varchar(20),
#   rental_duration    smallint NOT NULL,
#   length             smallint NOT NULL,
#   rating             varchar(5) NOT NULL,
#   special_features   varchar(60) NOT NULL
# );
# CREATE TABLE dimStore
# (
#   store_key           SERIAL PRIMARY KEY,
#   store_id            smallint NOT NULL,
#   address             varchar(50) NOT NULL,
#   address2            varchar(50),
#   district            varchar(20) NOT NULL,
#   city                varchar(50) NOT NULL,
#   country             varchar(50) NOT NULL,
#   postal_code         varchar(10),
#   manager_first_name  varchar(45) NOT NULL,
#   manager_last_name   varchar(45) NOT NULL,
#   start_date          date NOT NULL,
#   end_date            date NOT NULL
# );
# CREATE TABLE factSales
# (
#   sales_key        SERIAL PRIMARY KEY,
#   date_key         INT NOT NULL REFERENCES dimDate(date_key),
#   customer_key     INT NOT NULL REFERENCES dimCustomer(customer_key),
#   movie_key        INT NOT NULL REFERENCES dimMovie(movie_key),
#   store_key        INT NOT NULL REFERENCES dimStore(store_key),
#   sales_amount     decimal(5,2) NOT NULL
# );
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# # STEP 5: ETL the data from 3NF tables to Facts & Dimension Tables

# %%
# %%sql
# INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)
# SELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,
#        date(payment_date)                                           AS date,
#        EXTRACT(year FROM payment_date)                              AS year,
#        EXTRACT(quarter FROM payment_date)                           AS quarter,
#        EXTRACT(month FROM payment_date)                             AS month,
#        EXTRACT(day FROM payment_date)                               AS day,
#        EXTRACT(week FROM payment_date)                              AS week,
#        CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend
# FROM payment;
#
#
# INSERT INTO dimCustomer (customer_key, customer_id, first_name, last_name, email, address, address2, district, city, country, postal_code, phone, active, create_date, start_date, end_date)
# SELECT c.customer_id AS customer_key,
#        c.customer_id,
#        c.first_name,
#        c.last_name,
#        c.email,
#        a.address,
#        a.address2,
#        a.district,
#        ci.city,
#        co.country,
#        a.postal_code,
#        a.phone,
#        c.active,
#        c.create_date,
#        now()         AS start_date,
#        now()         AS end_date
# FROM customer c
# JOIN address a  ON (c.address_id = a.address_id)
# JOIN city ci    ON (a.city_id = ci.city_id)
# JOIN country co ON (ci.country_id = co.country_id);
#
# INSERT INTO dimMovie (movie_key, film_id, title, description, release_year, language, original_language, rental_duration, length, rating, special_features)
# SELECT f.film_id      AS movie_key,
#        f.film_id,
#        f.title,
#        f.description,
#        f.release_year,
#        l.name         AS language,
#        orig_lang.name AS original_language,
#        f.rental_duration,
#        f.length,
#        f.rating,
#        f.special_features
# FROM film f
# JOIN language l              ON (f.language_id=l.language_id)
# LEFT JOIN language orig_lang ON (f.original_language_id = orig_lang.language_id);
#
# INSERT INTO dimStore (store_key, store_id, address, address2, district, city, country, postal_code, manager_first_name, manager_last_name, start_date, end_date)
# SELECT s.store_id    AS store_key,
#        s.store_id,
#        a.address,
#        a.address2,
#        a.district,
#        c.city,
#        co.country,
#        a.postal_code,
#        st.first_name AS manager_first_name,
#        st.last_name  AS manager_last_name,
#        now()         AS start_date,
#        now()         AS end_date
# FROM store s
# JOIN staff st   ON (s.manager_staff_id = st.staff_id)
# JOIN address a  ON (s.address_id = a.address_id)
# JOIN city c     ON (a.city_id = c.city_id)
# JOIN country co ON (c.country_id = co.country_id);
#
# INSERT INTO factSales (date_key, customer_key, movie_key, store_key, sales_amount)
# SELECT TO_CHAR(p.payment_date :: DATE, 'yyyyMMDD')::integer AS date_key ,
#        p.customer_id                                        AS customer_key,
#        i.film_id                                            AS movie_key,
#        i.store_id                                           AS store_key,
#        p.amount                                             AS sales_amount
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id );
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 40 rows affected.
# 599 rows affected.
# 1000 rows affected.
# 2 rows affected.
# 16049 rows affected.
# []

# %% [markdown]
# # STEP 6: Repeat the computation from the facts & dimension table

# %% [markdown]
# ## 6.1 Facts Table has all the needed dimensions, no need for deep joins

# %%
# %%time
# %%sql
SELECT movie_key, date_key, customer_key, sales_amount
FROM factSales 
limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# CPU times: user 2.29 ms, sys: 307 µs, total: 2.6 ms
# Wall time: 5.38 ms
# [(870, 20170124, 269, Decimal('1.99')),
#  (651, 20170125, 269, Decimal('0.99')),
#  (818, 20170128, 269, Decimal('6.99')),
#  (249, 20170129, 269, Decimal('0.99')),
#  (159, 20170129, 269, Decimal('4.99'))]

# %% [markdown]
# ## 6.2 Join fact table with dimensions to replace keys with attributes

# %%
# %%time
# %%sql
SELECT dimMovie.title, dimDate.month, dimCustomer.city, sales_amount
FROM factSales 
JOIN dimMovie on (dimMovie.movie_key = factSales.movie_key)
JOIN dimDate on (dimDate.date_key = factSales.date_key)
JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# CPU times: user 3.75 ms, sys: 499 µs, total: 4.25 ms
# Wall time: 9.72 ms
# [('SWARM GOLD', 1, 'Salinas', Decimal('1.99')),
#  ('PACKER MADIGAN', 1, 'Salinas', Decimal('0.99')),
#  ('SOMETHING DUCK', 1, 'Salinas', Decimal('6.99')),
#  ('DRACULA CRYSTAL', 1, 'Salinas', Decimal('0.99')),
#  ('CLOSER BANG', 1, 'Salinas', Decimal('4.99'))]

# %%
# %%time
# %%sql
SELECT dimMovie.title, dimDate.month, dimCustomer.city, sum(sales_amount) as revenue
FROM factSales 
JOIN dimMovie    on (dimMovie.movie_key      = factSales.movie_key)
JOIN dimDate     on (dimDate.date_key         = factSales.date_key)
JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
group by (dimMovie.title, dimDate.month, dimCustomer.city)
order by dimMovie.title, dimDate.month, dimCustomer.city, revenue desc
limit 20;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 20 rows affected.
# CPU times: user 1.71 ms, sys: 3.71 ms, total: 5.43 ms
# Wall time: 48.2 ms
# [('ACADEMY DINOSAUR', 1, 'Celaya', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 1, 'Cianjur', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 2, 'San Lorenzo', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 2, 'Sullana', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 2, 'Udaipur', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Almirante Brown', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 3, 'Goinia', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Kaliningrad', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Kurashiki', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Livorno', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Nukualofa', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Rajkot', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 3, 'Sivas', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 3, 'Tabriz', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 4, 'Charlotte Amalie', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'Hamilton', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'Jos Azueta', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 4, 'Lipetsk', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'London', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'Pjatigorsk', Decimal('1.99'))]

# %%
# %%time
# %%sql
SELECT f.title, EXTRACT(month FROM p.payment_date) as month, ci.city, sum(p.amount) as revenue
FROM payment p
JOIN rental r    ON ( p.rental_id = r.rental_id )
JOIN inventory i ON ( r.inventory_id = i.inventory_id )
JOIN film f ON ( i.film_id = f.film_id)
JOIN customer c  ON ( p.customer_id = c.customer_id )
JOIN address a ON ( c.address_id = a.address_id )
JOIN city ci ON ( a.city_id = ci.city_id )
group by (f.title, month, ci.city)
order by f.title, month, ci.city, revenue desc;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 15992 rows affected.
# CPU times: user 42.8 ms, sys: 0 ns, total: 42.8 ms
# Wall time: 119 ms
# [('ACADEMY DINOSAUR', 1.0, 'Celaya', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 1.0, 'Cianjur', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 2.0, 'San Lorenzo', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 2.0, 'Sullana', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 2.0, 'Udaipur', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3.0, 'Almirante Brown', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 3.0, 'Goinia', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3.0, 'Kaliningrad', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3.0, 'Kurashiki', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3.0, 'Livorno', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3.0, 'Nukualofa', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3.0, 'Rajkot', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 3.0, 'Sivas', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 3.0, 'Tabriz', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 4.0, 'Charlotte Amalie', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4.0, 'Hamilton', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4.0, 'Jos Azueta', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 4.0, 'Lipetsk', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4.0, 'London', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4.0, 'Pjatigorsk', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 4.0, 'Sucre', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4.0, 'Tel Aviv-Jaffa', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4.0, 'Vila Velha', Decimal('0.99')),
#  ('ACE GOLDFINGER', 3.0, 'Binzhou', Decimal('8.99')),
#  ('ACE GOLDFINGER', 3.0, 'Kumbakonam', Decimal('4.99')),
#  ('ACE GOLDFINGER', 3.0, 'Pereira', Decimal('8.99')),
#  ('ACE GOLDFINGER', 3.0, 'Touliu', Decimal('9.99')),
#  ('ACE GOLDFINGER', 4.0, 'Simferopol', Decimal('9.99')),
#  ('ACE GOLDFINGER', 4.0, 'Soshanguve', Decimal('4.99')),
#  ('ACE GOLDFINGER', 5.0, 'Balikesir', Decimal('4.99')),
#  ('ADAPTATION HOLES', 1.0, 'Shikarpur', Decimal('2.99')),
#  ('ADAPTATION HOLES', 2.0, 'Jelets', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3.0, 'Cayenne', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3.0, 'Coacalco de Berriozbal', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3.0, 'Salinas', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3.0, 'Santa Brbara dOeste', Decimal('2.99')),
#  ('ADAPTATION HOLES', 3.0, 'Sasebo', Decimal('4.99')),
#  ('ADAPTATION HOLES', 3.0, 'al-Qatif', Decimal('2.99')),
#  ('ADAPTATION HOLES', 4.0, 'Jodhpur', Decimal('2.99')),
#  ('ADAPTATION HOLES', 4.0, 'Miraj', Decimal('2.99')),
#  ('ADAPTATION HOLES', 4.0, 'Ogbomosho', Decimal('2.99')),
#  ('ADAPTATION HOLES', 4.0, 'Urawa', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 1.0, 'Hidalgo', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', 1.0, 'Tuguegarao', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', 2.0, 'Changzhou', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 2.0, 'Crdoba', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 3.0, 'Aparecida de Goinia', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 3.0, 'Atinsk', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 3.0, 'Avellaneda', Decimal('6.99')),
#  ('AFFAIR PREJUDICE', 3.0, 'Caracas', Decimal('6.99')),
#  ('AFFAIR PREJUDICE', 3.0, 'Laiwu', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 3.0, 'Rancagua', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'Chiayi', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'Ciomas', Decimal('5.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'Lublin', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'Malm', Decimal('5.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'Palghat (Palakkad)', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'Qomsheh', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'Saint-Denis', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'San Felipe de Puerto Plata', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'Sirjan', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'Sokoto', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', 4.0, 'Tiefa', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4.0, 's-Hertogenbosch', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 5.0, 'Caracas', Decimal('2.99')),
#  ('AFRICAN EGG', 1.0, 'Ivanovo', Decimal('3.99')),
#  ('AFRICAN EGG', 2.0, 'Okayama', Decimal('3.99')),
#  ('AFRICAN EGG', 2.0, 'Richmond Hill', Decimal('4.99')),
#  ('AFRICAN EGG', 3.0, 'Rampur', Decimal('3.99')),
#  ('AFRICAN EGG', 3.0, 'Smolensk', Decimal('4.99')),
#  ('AFRICAN EGG', 3.0, 'Tokat', Decimal('2.99')),
#  ('AFRICAN EGG', 4.0, 'Jedda', Decimal('4.99')),
#  ('AFRICAN EGG', 4.0, 'Jhansi', Decimal('2.99')),
#  ('AFRICAN EGG', 4.0, 'Kitwe', Decimal('4.99')),
#  ('AFRICAN EGG', 4.0, 'Salzburg', Decimal('5.99')),
#  ('AFRICAN EGG', 4.0, 'York', Decimal('4.99')),
#  ('AFRICAN EGG', 5.0, 'al-Manama', Decimal('2.99')),
#  ('AGENT TRUMAN', 1.0, 'Coatzacoalcos', Decimal('8.99')),
#  ('AGENT TRUMAN', 1.0, 'Izumisano', Decimal('5.99')),
#  ('AGENT TRUMAN', 2.0, 'Antofagasta', Decimal('3.99')),
#  ('AGENT TRUMAN', 2.0, 'Moscow', Decimal('8.99')),
#  ('AGENT TRUMAN', 2.0, 'Taizz', Decimal('6.99')),
#  ('AGENT TRUMAN', 3.0, 'Bhilwara', Decimal('8.99')),
#  ('AGENT TRUMAN', 3.0, 'Chisinau', Decimal('4.99')),
#  ('AGENT TRUMAN', 3.0, 'Citrus Heights', Decimal('6.99')),
#  ('AGENT TRUMAN', 3.0, 'Emeishan', Decimal('3.99')),
#  ('AGENT TRUMAN', 3.0, 'Luzinia', Decimal('3.99')),
#  ('AGENT TRUMAN', 3.0, 'Mogiljov', Decimal('6.99')),
#  ('AGENT TRUMAN', 3.0, 'Omdurman', Decimal('7.99')),
#  ('AGENT TRUMAN', 3.0, 'Sunnyvale', Decimal('4.99')),
#  ('AGENT TRUMAN', 3.0, 'Usak', Decimal('7.99')),
#  ('AGENT TRUMAN', 4.0, 'Aurora', Decimal('4.99')),
#  ('AGENT TRUMAN', 4.0, 'Huixquilucan', Decimal('4.99')),
#  ('AGENT TRUMAN', 4.0, 'Matsue', Decimal('5.99')),
#  ('AGENT TRUMAN', 4.0, 'Nantou', Decimal('2.99')),
#  ('AGENT TRUMAN', 4.0, 'Pontianak', Decimal('7.99')),
#  ('AGENT TRUMAN', 4.0, 'Quilmes', Decimal('2.99')),
#  ('AGENT TRUMAN', 4.0, 'Tafuna', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 2.0, 'Cavite', Decimal('7.99')),
#  ('AIRPLANE SIERRA', 2.0, 'Lubumbashi', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3.0, 'Ibirit', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3.0, 'Iwakuni', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3.0, 'Johannesburg', Decimal('7.99')),
#  ('AIRPLANE SIERRA', 3.0, 'Jurez', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3.0, 'Mahajanga', Decimal('5.99')),
#  ('AIRPLANE SIERRA', 3.0, 's-Hertogenbosch', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4.0, 'Bhusawal', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4.0, 'Kuwana', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4.0, 'Salamanca', Decimal('5.99')),
#  ('AIRPLANE SIERRA', 4.0, 'Sincelejo', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4.0, 'Tsuyama', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4.0, 'Yuncheng', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4.0, 'Zalantun', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 1.0, 'Okinawa', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 1.0, 'Pemalang', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 1.0, 'Taguig', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 2.0, 'Molodetno', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 2.0, 'Portoviejo', Decimal('6.99')),
#  ('AIRPORT POLLOCK', 2.0, 'Vaduz', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 3.0, 'Augusta-Richmond County', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 3.0, 'Lilongwe', Decimal('7.99')),
#  ('AIRPORT POLLOCK', 3.0, 'Lublin', Decimal('6.99')),
#  ('AIRPORT POLLOCK', 3.0, 'Peoria', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 3.0, 'Yangor', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 4.0, 'Bamenda', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 4.0, 'Dhaka', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 4.0, 'Erlangen', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 4.0, 'Fukuyama', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 4.0, 'Palghat (Palakkad)', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 4.0, 'San Juan Bautista Tuxtepec', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 4.0, 'Sanaa', Decimal('4.99')),
#  ('ALABAMA DEVIL', 3.0, 'Greensboro', Decimal('5.99')),
#  ('ALABAMA DEVIL', 3.0, 'Halifax', Decimal('7.99')),
#  ('ALABAMA DEVIL', 3.0, 'Otsu', Decimal('8.99')),
#  ('ALABAMA DEVIL', 3.0, 'Sunnyvale', Decimal('2.99')),
#  ('ALABAMA DEVIL', 3.0, 'Zaoyang', Decimal('5.99')),
#  ('ALABAMA DEVIL', 4.0, 'Arlington', Decimal('8.99')),
#  ('ALABAMA DEVIL', 4.0, 'Asuncin', Decimal('5.99')),
#  ('ALABAMA DEVIL', 4.0, 'Changhwa', Decimal('4.99')),
#  ('ALABAMA DEVIL', 4.0, 'Eskisehir', Decimal('2.99')),
#  ('ALABAMA DEVIL', 4.0, 'Kanazawa', Decimal('4.99')),
#  ('ALABAMA DEVIL', 4.0, 'Mit Ghamr', Decimal('2.99')),
#  ('ALABAMA DEVIL', 4.0, 'Probolinggo', Decimal('8.99')),
#  ('ALADDIN CALENDAR', 2.0, 'Kaduna', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 2.0, 'Kisumu', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 2.0, 'La Plata', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 2.0, 'Olomouc', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3.0, 'Adoni', Decimal('6.99')),
#  ('ALADDIN CALENDAR', 3.0, 'Balaiha', Decimal('6.99')),
#  ('ALADDIN CALENDAR', 3.0, 'Coacalco de Berriozbal', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3.0, 'Deba Habe', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3.0, 'Dos Quebradas', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3.0, 'Halisahar', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3.0, 'Mwanza', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3.0, 'Ranchi', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3.0, 'Sogamoso', Decimal('7.99')),
#  ('ALADDIN CALENDAR', 3.0, 'Zalantun', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4.0, 'Effon-Alaiye', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4.0, 'Esfahan', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4.0, 'Gulbarga', Decimal('7.99')),
#  ('ALADDIN CALENDAR', 4.0, 'Hodeida', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4.0, 'Izumisano', Decimal('7.99')),
#  ('ALADDIN CALENDAR', 4.0, 'Monclova', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4.0, 'Okinawa', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4.0, 'Stockport', Decimal('5.99')),
#  ('ALADDIN CALENDAR', 4.0, 'Valencia', Decimal('7.99')),
#  ('ALAMO VIDEOTAPE', 1.0, 'Arecibo', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 1.0, 'Yuzhou', Decimal('3.99')),
#  ('ALAMO VIDEOTAPE', 2.0, 'Meixian', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 2.0, 'Rio Claro', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 2.0, 'Tarlac', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Baicheng', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Bat Yam', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Ife', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Jinchang', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Myingyan', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Papeete', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Pudukkottai', Decimal('3.99')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Stara Zagora', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3.0, 'Tanauan', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Berhampore (Baharampur)', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Duisburg', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Emmen', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Grand Prairie', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Idfu', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Lapu-Lapu', Decimal('1.98')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Owo', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Pemalang', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4.0, 'Zeleznogorsk', Decimal('0.99')),
#  ('ALASKA PHANTOM', 1.0, 'Nezahualcyotl', Decimal('0.99')),
#  ('ALASKA PHANTOM', 1.0, 'Zhezqazghan', Decimal('2.99')),
#  ('ALASKA PHANTOM', 2.0, 'Braslia', Decimal('2.99')),
#  ('ALASKA PHANTOM', 2.0, 'Maring', Decimal('0.99')),
#  ('ALASKA PHANTOM', 2.0, 'Sterling Heights', Decimal('1.99')),
#  ('ALASKA PHANTOM', 2.0, 'Touliu', Decimal('0.99')),
#  ('ALASKA PHANTOM', 2.0, 'al-Qadarif', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3.0, 'Dhule (Dhulia)', Decimal('2.99')),
#  ('ALASKA PHANTOM', 3.0, 'Laohekou', Decimal('1.99')),
#  ('ALASKA PHANTOM', 3.0, 'Nabereznyje Telny', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3.0, 'Nantou', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3.0, 'Peoria', Decimal('3.99')),
#  ('ALASKA PHANTOM', 3.0, 'Saint Louis', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3.0, 'Szkesfehrvr', Decimal('1.99')),
#  ('ALASKA PHANTOM', 3.0, 'Zhezqazghan', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4.0, 'Baicheng', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4.0, 'Bhilwara', Decimal('3.99')),
#  ('ALASKA PHANTOM', 4.0, 'Dhule (Dhulia)', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4.0, 'Lhokseumawe', Decimal('1.99')),
#  ('ALASKA PHANTOM', 4.0, 'Ljubertsy', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4.0, 'Mandi Bahauddin', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4.0, 'Niznekamsk', Decimal('2.99')),
#  ('ALASKA PHANTOM', 4.0, 'Omdurman', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4.0, 'Tiefa', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4.0, 'Xiangtan', Decimal('1.99')),
#  ('ALASKA PHANTOM', 4.0, 'al-Hawiya', Decimal('0.99')),
#  ('ALI FOREVER', 3.0, 'Esfahan', Decimal('5.99')),
#  ('ALI FOREVER', 3.0, 'Lubumbashi', Decimal('4.99')),
#  ('ALI FOREVER', 3.0, 'Ourense (Orense)', Decimal('9.99')),
#  ('ALI FOREVER', 3.0, 'Sharja', Decimal('4.99')),
#  ('ALI FOREVER', 4.0, 'Cuauhtmoc', Decimal('7.99')),
#  ('ALI FOREVER', 4.0, 'Jakarta', Decimal('4.99')),
#  ('ALI FOREVER', 4.0, 'Maikop', Decimal('5.99')),
#  ('ALI FOREVER', 4.0, 'Vaduz', Decimal('4.99')),
#  ('ALI FOREVER', 5.0, 'Huixquilucan', Decimal('4.99')),
#  ('ALIEN CENTER', 1.0, 'Caracas', Decimal('2.99')),
#  ('ALIEN CENTER', 1.0, 'Escobar', Decimal('2.99')),
#  ('ALIEN CENTER', 2.0, 'Baiyin', Decimal('2.99')),
#  ('ALIEN CENTER', 2.0, 'Lengshuijiang', Decimal('2.99')),
#  ('ALIEN CENTER', 2.0, 'Rancagua', Decimal('4.99')),
#  ('ALIEN CENTER', 3.0, 'Bag', Decimal('2.99')),
#  ('ALIEN CENTER', 3.0, 'Hsichuh', Decimal('2.99')),
#  ('ALIEN CENTER', 3.0, 'Huejutla de Reyes', Decimal('2.99')),
#  ('ALIEN CENTER', 3.0, 'Kragujevac', Decimal('2.99')),
#  ('ALIEN CENTER', 3.0, 'Memphis', Decimal('6.99')),
#  ('ALIEN CENTER', 3.0, 'Nagareyama', Decimal('2.99')),
#  ('ALIEN CENTER', 3.0, 'San Felipe de Puerto Plata', Decimal('5.99')),
#  ('ALIEN CENTER', 3.0, 'Sanya', Decimal('4.99')),
#  ('ALIEN CENTER', 3.0, 'Songkhla', Decimal('2.99')),
#  ('ALIEN CENTER', 4.0, 'Cuman', Decimal('2.99')),
#  ('ALIEN CENTER', 4.0, 'El Fuerte', Decimal('4.99')),
#  ('ALIEN CENTER', 4.0, 'Emeishan', Decimal('6.99')),
#  ('ALIEN CENTER', 4.0, 'Juazeiro do Norte', Decimal('3.99')),
#  ('ALIEN CENTER', 4.0, 'Richmond Hill', Decimal('2.99')),
#  ('ALIEN CENTER', 4.0, 'Shahr-e Kord', Decimal('2.99')),
#  ('ALIEN CENTER', 4.0, 'Xiangfan', Decimal('6.99')),
#  ('ALIEN CENTER', 4.0, 'Zhezqazghan', Decimal('5.99')),
#  ('ALLEY EVOLUTION', 1.0, 'Najafabad', Decimal('5.99')),
#  ('ALLEY EVOLUTION', 2.0, 'Lancaster', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 2.0, 'Mexicali', Decimal('6.99')),
#  ('ALLEY EVOLUTION', 3.0, 'Aden', Decimal('4.99')),
#  ('ALLEY EVOLUTION', 3.0, 'Jos Azueta', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 3.0, 'Kalisz', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 3.0, 'Ponce', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 3.0, 'Shahr-e Kord', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 3.0, 'Tuguegarao', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4.0, 'Esfahan', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4.0, 'NDjamna', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4.0, 'Shikarpur', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4.0, 'Tonghae', Decimal('4.99')),
#  ('ALLEY EVOLUTION', 4.0, 'Tsaotun', Decimal('2.99')),
#  ('ALONE TRIP', 1.0, 'Arak', Decimal('0.99')),
#  ('ALONE TRIP', 2.0, 'Almirante Brown', Decimal('0.99')),
#  ('ALONE TRIP', 2.0, 'Tuguegarao', Decimal('3.99')),
#  ('ALONE TRIP', 3.0, 'Kamjanets-Podilskyi', Decimal('3.99')),
#  ('ALONE TRIP', 3.0, 'Lungtan', Decimal('2.99')),
#  ('ALONE TRIP', 3.0, 'NDjamna', Decimal('0.99')),
#  ('ALONE TRIP', 3.0, 'Sincelejo', Decimal('2.99')),
#  ('ALONE TRIP', 3.0, 'Sousse', Decimal('4.99')),
#  ('ALONE TRIP', 3.0, 'Sterling Heights', Decimal('4.99')),
#  ('ALONE TRIP', 3.0, 'Tarsus', Decimal('2.99')),
#  ('ALONE TRIP', 3.0, 'Vinh', Decimal('1.99')),
#  ('ALONE TRIP', 4.0, 'Arecibo', Decimal('1.99')),
#  ('ALONE TRIP', 4.0, 'Cabuyao', Decimal('1.99')),
#  ('ALONE TRIP', 4.0, 'Hami', Decimal('6.99')),
#  ('ALONE TRIP', 4.0, 'Huixquilucan', Decimal('4.99')),
#  ('ALONE TRIP', 4.0, 'Mwanza', Decimal('6.99')),
#  ('ALONE TRIP', 4.0, 'Syktyvkar', Decimal('6.99')),
#  ('ALONE TRIP', 5.0, 'Tanza', Decimal('0.99')),
#  ('ALTER VICTORY', 1.0, 'Ezhou', Decimal('0.99')),
#  ('ALTER VICTORY', 1.0, 'Vinh', Decimal('0.99')),
#  ('ALTER VICTORY', 2.0, 'Charlotte Amalie', Decimal('0.99')),
#  ('ALTER VICTORY', 2.0, 'Cianjur', Decimal('0.99')),
#  ('ALTER VICTORY', 2.0, 'Purnea (Purnia)', Decimal('0.99')),
#  ('ALTER VICTORY', 3.0, 'Alessandria', Decimal('0.99')),
#  ('ALTER VICTORY', 3.0, 'Bijapur', Decimal('0.99')),
#  ('ALTER VICTORY', 3.0, 'Kamyin', Decimal('0.99')),
#  ('ALTER VICTORY', 3.0, 'Korolev', Decimal('0.99')),
#  ('ALTER VICTORY', 3.0, 'Meixian', Decimal('0.99')),
#  ('ALTER VICTORY', 3.0, 'Tongliao', Decimal('1.99')),
#  ('ALTER VICTORY', 4.0, 'Addis Abeba', Decimal('1.99')),
#  ('ALTER VICTORY', 4.0, 'Avellaneda', Decimal('0.99')),
#  ('ALTER VICTORY', 4.0, 'Bandar Seri Begawan', Decimal('0.99')),
#  ('ALTER VICTORY', 4.0, 'Boksburg', Decimal('0.99')),
#  ('ALTER VICTORY', 4.0, 'Kitwe', Decimal('3.99')),
#  ('ALTER VICTORY', 4.0, 'Nantou', Decimal('0.99')),
#  ('ALTER VICTORY', 4.0, 'Shaoguan', Decimal('3.99')),
#  ('ALTER VICTORY', 4.0, 'Shimonoseki', Decimal('0.99')),
#  ('ALTER VICTORY', 4.0, 'Sirjan', Decimal('3.99')),
#  ('ALTER VICTORY', 4.0, 'Tiefa', Decimal('0.99')),
#  ('ALTER VICTORY', 4.0, 'Urawa', Decimal('0.99')),
#  ('AMADEUS HOLY', 1.0, 'La Plata', Decimal('0.99')),
#  ('AMADEUS HOLY', 2.0, 'Denizli', Decimal('0.99')),
#  ('AMADEUS HOLY', 2.0, 'Jakarta', Decimal('0.99')),
#  ('AMADEUS HOLY', 2.0, 'Kurashiki', Decimal('0.99')),
#  ('AMADEUS HOLY', 2.0, 'Myingyan', Decimal('0.99')),
#  ('AMADEUS HOLY', 3.0, 'Araatuba', Decimal('0.99')),
#  ('AMADEUS HOLY', 3.0, 'Citt del Vaticano', Decimal('1.99')),
#  ('AMADEUS HOLY', 3.0, 'Joliet', Decimal('3.99')),
#  ('AMADEUS HOLY', 3.0, 'Laredo', Decimal('0.99')),
#  ('AMADEUS HOLY', 3.0, 'Matamoros', Decimal('0.99')),
#  ('AMADEUS HOLY', 3.0, 'Shubra al-Khayma', Decimal('3.99')),
#  ('AMADEUS HOLY', 3.0, 'Vila Velha', Decimal('0.99')),
#  ('AMADEUS HOLY', 4.0, 'Arak', Decimal('0.99')),
#  ('AMADEUS HOLY', 4.0, 'Bilbays', Decimal('1.99')),
#  ('AMADEUS HOLY', 4.0, 'Hohhot', Decimal('1.99')),
#  ('AMADEUS HOLY', 4.0, 'Jining', Decimal('0.99')),
#  ('AMADEUS HOLY', 4.0, 'Nabereznyje Telny', Decimal('0.99')),
#  ('AMADEUS HOLY', 4.0, 'Pjatigorsk', Decimal('0.99')),
#  ('AMADEUS HOLY', 4.0, 'Poos de Caldas', Decimal('3.99')),
#  ('AMADEUS HOLY', 4.0, 'Warren', Decimal('1.99')),
#  ('AMADEUS HOLY', 5.0, 'London', Decimal('0.99')),
#  ('AMELIE HELLFIGHTERS', 2.0, 'Acua', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 2.0, 'Ipoh', Decimal('5.99')),
#  ('AMELIE HELLFIGHTERS', 3.0, 'Anpolis', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 3.0, 'Sterling Heights', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 3.0, 'Tonghae', Decimal('8.99')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Botshabelo', Decimal('5.99')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Funafuti', Decimal('9.99')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Madiun', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'Meixian', Decimal('6.99')),
#  ('AMELIE HELLFIGHTERS', 4.0, 'So Bernardo do Campo', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 1.0, 'Callao', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 1.0, 'Juazeiro do Norte', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 2.0, 'Dos Quebradas', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 2.0, 'El Fuerte', Decimal('6.99')),
#  ('AMERICAN CIRCUS', 2.0, 'Oulu', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 3.0, 'Bayugan', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 3.0, 'Bergamo', Decimal('5.99')),
#  ('AMERICAN CIRCUS', 3.0, 'Bijapur', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 3.0, 'Changhwa', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 3.0, 'Imus', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 3.0, 'Konotop', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 3.0, 'Nagaon', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 3.0, 'Oulu', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 4.0, 'Benguela', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 4.0, 'Bydgoszcz', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 4.0, 'Cabuyao', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 4.0, 'Halle/Saale', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 4.0, 'Juazeiro do Norte', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 4.0, 'Nador', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 4.0, 'Saint-Denis', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 4.0, 'Tiefa', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 5.0, 'Lipetsk', Decimal('4.99')),
#  ('AMISTAD MIDSUMMER', 2.0, 'Akron', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 2.0, 'Mysore', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 2.0, 'Shimonoseki', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Elista', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Garland', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Jastrzebie-Zdrj', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Kolpino', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Miyakonojo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Vijayawada', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3.0, 'Zanzibar', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3.0, 's-Hertogenbosch', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Apeldoorn', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Arecibo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Avellaneda', Decimal('4.99')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Cavite', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Effon-Alaiye', Decimal('5.99')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Nantou', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Sasebo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Usak', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4.0, 'Xinxiang', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', 5.0, 'Imus', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 1.0, 'Fengshan', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 1.0, 'Tarsus', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Athenai', Decimal('6.99')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Dallas', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Kermanshah', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Nanyang', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', 2.0, 'Otsu', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Botshabelo', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Haldia', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Roanoke', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Shanwei', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 3.0, 'Uttarpara-Kotrung', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Batman', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Caracas', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Charlotte Amalie', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Jelets', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Molodetno', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Sambhal', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 4.0, 'San Juan Bautista Tuxtepec', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Tanza', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', 4.0, 'Vitria de Santo Anto', Decimal('0.99')),
#  ('ANALYZE HOOSIERS', 2.0, 'Saint Louis', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 2.0, 'Xintai', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 2.0, 'Yuncheng', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 3.0, 'Bijapur', Decimal('3.99')),
#  ('ANALYZE HOOSIERS', 3.0, 'Ciudad del Este', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 3.0, 'Joliet', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 3.0, 'Tartu', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 4.0, 'Ambattur', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 4.0, 'Celaya', Decimal('3.99')),
#  ('ANALYZE HOOSIERS', 4.0, 'Citrus Heights', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 4.0, 'Kurashiki', Decimal('5.99')),
#  ('ANALYZE HOOSIERS', 4.0, 'Kuwana', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 4.0, 'Usak', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 4.0, 'Valparai', Decimal('3.99')),
#  ('ANGELS LIFE', 1.0, 'Adana', Decimal('6.99')),
#  ('ANGELS LIFE', 1.0, 'Salala', Decimal('8.99')),
#  ('ANGELS LIFE', 2.0, 'Arecibo', Decimal('3.99')),
#  ('ANGELS LIFE', 2.0, 'Kermanshah', Decimal('3.99')),
#  ('ANGELS LIFE', 2.0, 'Urawa', Decimal('2.99')),
#  ('ANGELS LIFE', 3.0, 'Fukuyama', Decimal('3.99')),
#  ('ANGELS LIFE', 3.0, 'Greensboro', Decimal('2.99')),
#  ('ANGELS LIFE', 3.0, 'Kakamigahara', Decimal('2.99')),
#  ('ANGELS LIFE', 3.0, 'Nagareyama', Decimal('5.99')),
#  ('ANGELS LIFE', 3.0, 'Salamanca', Decimal('8.99')),
#  ('ANGELS LIFE', 3.0, 'San Juan Bautista Tuxtepec', Decimal('6.99')),
#  ('ANGELS LIFE', 3.0, 'Teboksary', Decimal('6.99')),
#  ('ANGELS LIFE', 3.0, 'Wroclaw', Decimal('7.99')),
#  ('ANGELS LIFE', 4.0, 'Ambattur', Decimal('2.99')),
#  ('ANGELS LIFE', 4.0, 'Augusta-Richmond County', Decimal('2.99')),
#  ('ANGELS LIFE', 4.0, 'Carmen', Decimal('5.99')),
#  ('ANGELS LIFE', 4.0, 'Kakamigahara', Decimal('3.99')),
#  ('ANGELS LIFE', 4.0, 'Korolev', Decimal('7.99')),
#  ('ANGELS LIFE', 4.0, 'Olomouc', Decimal('2.99')),
#  ('ANGELS LIFE', 4.0, 'Rampur', Decimal('8.99')),
#  ('ANGELS LIFE', 4.0, 'Sharja', Decimal('6.99')),
#  ('ANGELS LIFE', 4.0, 'York', Decimal('2.99')),
#  ('ANNIE IDENTITY', 1.0, 'Jedda', Decimal('3.99')),
#  ('ANNIE IDENTITY', 1.0, 'Maring', Decimal('3.99')),
#  ('ANNIE IDENTITY', 1.0, 'Tel Aviv-Jaffa', Decimal('0.99')),
#  ('ANNIE IDENTITY', 2.0, 'Battambang', Decimal('2.99')),
#  ('ANNIE IDENTITY', 2.0, 'Ede', Decimal('5.99')),
#  ('ANNIE IDENTITY', 2.0, 'Goinia', Decimal('0.99')),
#  ('ANNIE IDENTITY', 2.0, 'Tama', Decimal('0.99')),
#  ('ANNIE IDENTITY', 3.0, 'Ashqelon', Decimal('4.99')),
#  ('ANNIE IDENTITY', 3.0, 'Czestochowa', Decimal('4.99')),
#  ('ANNIE IDENTITY', 3.0, 'Myingyan', Decimal('1.99')),
#  ('ANNIE IDENTITY', 3.0, 'Pangkal Pinang', Decimal('0.99')),
#  ('ANNIE IDENTITY', 3.0, 'Santa F', Decimal('2.99')),
#  ('ANNIE IDENTITY', 3.0, 'Shaoguan', Decimal('6.99')),
#  ('ANNIE IDENTITY', 3.0, 'Yuncheng', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4.0, 'Cabuyao', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4.0, 'Luzinia', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4.0, 'Oyo', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4.0, 'Szkesfehrvr', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4.0, 'Vilnius', Decimal('1.99')),
#  ('ANNIE IDENTITY', 4.0, 'Zanzibar', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4.0, 'Zaria', Decimal('5.99')),
#  ('ANNIE IDENTITY', 4.0, 'Zhoushan', Decimal('2.99')),
#  ('ANONYMOUS HUMAN', 2.0, 'Uruapan', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', 2.0, 'Varanasi (Benares)', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3.0, 'Basel', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3.0, 'Ezhou', Decimal('2.99')),
#  ('ANONYMOUS HUMAN', 3.0, 'Kowloon and New Kowloon', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3.0, 'La Romana', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3.0, 'San Bernardino', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3.0, 'Zhezqazghan', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', 4.0, 'Dhaka', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 4.0, 'Iwakuni', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 4.0, 'Kamakura', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', 4.0, 'Liepaja', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 4.0, 'Richmond Hill', Decimal('0.99')),
#  ('ANTHEM LUKE', 1.0, 'Lengshuijiang', Decimal('6.99')),
#  ('ANTHEM LUKE', 1.0, 'Pyongyang', Decimal('4.99')),
#  ('ANTHEM LUKE', 1.0, 'Uluberia', Decimal('4.99')),
#  ('ANTHEM LUKE', 2.0, 'Ashgabat', Decimal('4.99')),
#  ('ANTHEM LUKE', 2.0, 'Cuauhtmoc', Decimal('4.99')),
#  ('ANTHEM LUKE', 2.0, 'San Felipe del Progreso', Decimal('4.99')),
#  ('ANTHEM LUKE', 3.0, 'Acua', Decimal('4.99')),
#  ('ANTHEM LUKE', 3.0, 'Fukuyama', Decimal('4.99')),
#  ('ANTHEM LUKE', 3.0, 'Ozamis', Decimal('4.99')),
#  ('ANTHEM LUKE', 4.0, 'Boa Vista', Decimal('8.99')),
#  ('ANTHEM LUKE', 4.0, 'Changzhou', Decimal('4.99')),
#  ('ANTHEM LUKE', 4.0, 'Coacalco de Berriozbal', Decimal('4.99')),
#  ('ANTHEM LUKE', 4.0, 'Kirovo-Tepetsk', Decimal('4.99')),
#  ('ANTHEM LUKE', 4.0, 'Kuwana', Decimal('5.99')),
#  ('ANTHEM LUKE', 4.0, 'Lhokseumawe', Decimal('8.99')),
#  ('ANTITRUST TOMATOES', 1.0, 'Erlangen', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 1.0, 'Novoterkassk', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 2.0, 'Lapu-Lapu', Decimal('6.99')),
#  ('ANTITRUST TOMATOES', 2.0, 'Sharja', Decimal('3.99')),
#  ('ANTITRUST TOMATOES', 3.0, 'Malm', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 3.0, 'Pereira', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 4.0, 'Bhimavaram', Decimal('3.99')),
#  ('ANTITRUST TOMATOES', 4.0, 'Fuyu', Decimal('4.99')),
#  ('ANTITRUST TOMATOES', 4.0, 'Vijayawada', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 4.0, 'Ziguinchor', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', 1.0, 'Halle/Saale', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', 2.0, 'Araatuba', Decimal('4.99')),
#  ('ANYTHING SAVANNAH', 2.0, 'Mexicali', Decimal('6.99')),
#  ('ANYTHING SAVANNAH', 3.0, 'Cam Ranh', Decimal('3.99')),
#  ('ANYTHING SAVANNAH', 3.0, 'El Monte', Decimal('5.99')),
#  ('ANYTHING SAVANNAH', 3.0, 'Gandhinagar', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', 3.0, 'Yangor', Decimal('7.99')),
#  ('ANYTHING SAVANNAH', 4.0, 'Banjul', Decimal('7.99')),
#  ('ANYTHING SAVANNAH', 4.0, 'Zaoyang', Decimal('2.99')),
#  ('APACHE DIVINE', 1.0, 'Cavite', Decimal('4.99')),
#  ('APACHE DIVINE', 1.0, 'Mukateve', Decimal('7.99')),
#  ('APACHE DIVINE', 1.0, 'So Leopoldo', Decimal('4.99')),
#  ('APACHE DIVINE', 2.0, 'Bamenda', Decimal('4.99')),
#  ('APACHE DIVINE', 2.0, 'Cam Ranh', Decimal('4.99')),
#  ('APACHE DIVINE', 2.0, 'Iwaki', Decimal('4.99')),
#  ('APACHE DIVINE', 2.0, 'Taizz', Decimal('4.99')),
#  ('APACHE DIVINE', 3.0, 'Balikesir', Decimal('6.99')),
#  ('APACHE DIVINE', 3.0, 'Boksburg', Decimal('7.99')),
#  ('APACHE DIVINE', 3.0, 'El Fuerte', Decimal('6.99')),
#  ('APACHE DIVINE', 3.0, 'Guadalajara', Decimal('4.99')),
#  ('APACHE DIVINE', 3.0, 'Kanazawa', Decimal('4.99')),
#  ('APACHE DIVINE', 3.0, 'Maikop', Decimal('5.99')),
#  ('APACHE DIVINE', 3.0, 'Moscow', Decimal('5.99')),
#  ('APACHE DIVINE', 3.0, 'Okinawa', Decimal('8.99')),
#  ('APACHE DIVINE', 3.0, 'Sorocaba', Decimal('4.99')),
#  ('APACHE DIVINE', 3.0, 'Urawa', Decimal('4.99')),
#  ('APACHE DIVINE', 3.0, 'Zanzibar', Decimal('4.99')),
#  ('APACHE DIVINE', 4.0, 'Bandar Seri Begawan', Decimal('4.99')),
#  ('APACHE DIVINE', 4.0, 'Carmen', Decimal('4.99')),
#  ('APACHE DIVINE', 4.0, 'Greensboro', Decimal('4.99')),
#  ('APACHE DIVINE', 4.0, 'Jaffna', Decimal('4.99')),
#  ('APACHE DIVINE', 4.0, 'Kimberley', Decimal('5.99')),
#  ('APACHE DIVINE', 4.0, 'Malm', Decimal('4.99')),
#  ('APACHE DIVINE', 4.0, 'Mit Ghamr', Decimal('6.99')),
#  ('APACHE DIVINE', 4.0, 'Oshawa', Decimal('4.99')),
#  ('APACHE DIVINE', 4.0, 'Pereira', Decimal('5.99')),
#  ('APACHE DIVINE', 4.0, 'Robamba', Decimal('4.99')),
#  ('APACHE DIVINE', 4.0, 'Taguig', Decimal('5.99')),
#  ('APACHE DIVINE', 4.0, 'Tiefa', Decimal('4.99')),
#  ('APACHE DIVINE', 4.0, 'York', Decimal('7.99')),
#  ('APOCALYPSE FLAMINGOS', 2.0, 'Kalisz', Decimal('5.99')),
#  ('APOCALYPSE FLAMINGOS', 3.0, 'Chandrapur', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 3.0, 'Ikerre', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 4.0, 'Belm', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 4.0, 'Blumenau', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 4.0, 'Ruse', Decimal('4.99')),
#  ('ARABIA DOGMA', 1.0, 'Tartu', Decimal('0.99')),
#  ('ARABIA DOGMA', 2.0, 'Qalyub', Decimal('0.99')),
#  ('ARABIA DOGMA', 2.0, 'Toulouse', Decimal('0.99')),
#  ('ARABIA DOGMA', 3.0, 'Amroha', Decimal('0.99')),
#  ('ARABIA DOGMA', 3.0, 'La Plata', Decimal('3.99')),
#  ('ARABIA DOGMA', 3.0, 'London', Decimal('3.99')),
#  ('ARABIA DOGMA', 3.0, 'Lubumbashi', Decimal('0.99')),
#  ('ARABIA DOGMA', 3.0, 'Monclova', Decimal('3.99')),
#  ('ARABIA DOGMA', 3.0, 'Tokat', Decimal('1.99')),
#  ('ARABIA DOGMA', 4.0, 'Changzhou', Decimal('0.99')),
#  ('ARABIA DOGMA', 4.0, 'Lapu-Lapu', Decimal('0.99')),
#  ('ARABIA DOGMA', 4.0, 'Tuguegarao', Decimal('0.99')),
#  ('ARABIA DOGMA', 4.0, 'Usak', Decimal('0.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Arlington', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Bhusawal', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Mwene-Ditu', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2.0, 'Tonghae', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Czestochowa', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Higashiosaka', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Kimberley', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Matsue', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Ondo', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Parbhani', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3.0, 'Zalantun', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Chapra', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Dadu', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Fuyu', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Gaziantep', Decimal('7.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Goinia', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Jamalpur', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Kamakura', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Myingyan', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Rio Claro', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Roanoke', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Usak', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Vicente Lpez', Decimal('7.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4.0, 'Zhezqazghan', Decimal('2.99')),
#  ('ARIZONA BANG', 2.0, 'Jalib al-Shuyukh', Decimal('5.99')),
#  ('ARIZONA BANG', 2.0, 'Szkesfehrvr', Decimal('2.99')),
#  ('ARIZONA BANG', 2.0, 'guas Lindas de Gois', Decimal('2.99')),
#  ('ARIZONA BANG', 3.0, 'Hamilton', Decimal('2.99')),
#  ('ARIZONA BANG', 3.0, 'Kowloon and New Kowloon', Decimal('7.99')),
#  ('ARIZONA BANG', 3.0, 'Molodetno', Decimal('4.99')),
#  ('ARIZONA BANG', 3.0, 'Nantou', Decimal('2.99')),
#  ('ARIZONA BANG', 3.0, 'Palghat (Palakkad)', Decimal('7.99')),
#  ('ARIZONA BANG', 3.0, 'Pontianak', Decimal('4.99')),
#  ('ARIZONA BANG', 3.0, 'Probolinggo', Decimal('2.99')),
#  ('ARIZONA BANG', 3.0, 'Rajkot', Decimal('7.99')),
#  ('ARIZONA BANG', 3.0, 'Salala', Decimal('2.99')),
#  ('ARIZONA BANG', 3.0, 'Shikarpur', Decimal('4.99')),
#  ('ARIZONA BANG', 3.0, 'Springs', Decimal('5.99')),
#  ('ARIZONA BANG', 3.0, 'Vijayawada', Decimal('6.99')),
#  ('ARIZONA BANG', 4.0, 'Battambang', Decimal('3.99')),
#  ('ARIZONA BANG', 4.0, 'Davao', Decimal('4.99')),
#  ('ARIZONA BANG', 4.0, 'Lancaster', Decimal('5.99')),
#  ('ARIZONA BANG', 4.0, 'Liepaja', Decimal('7.99')),
#  ('ARIZONA BANG', 4.0, 'Osmaniye', Decimal('2.99')),
#  ('ARIZONA BANG', 4.0, 'Saint-Denis', Decimal('2.99')),
#  ('ARMAGEDDON LOST', 1.0, 'Dallas', Decimal('3.99')),
#  ('ARMAGEDDON LOST', 2.0, 'Surakarta', Decimal('4.99')),
#  ('ARMAGEDDON LOST', 2.0, 'Tallahassee', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 3.0, 'Bhavnagar', Decimal('3.99')),
#  ('ARMAGEDDON LOST', 3.0, 'Dzerzinsk', Decimal('5.99')),
#  ('ARMAGEDDON LOST', 3.0, 'Hanoi', Decimal('1.99')),
#  ('ARMAGEDDON LOST', 3.0, 'NDjamna', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 3.0, 'Nanyang', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 3.0, 'Rio Claro', Decimal('1.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Ambattur', Decimal('2.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Bradford', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Cheju', Decimal('1.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Cianjur', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Hiroshima', Decimal('2.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Luzinia', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Nakhon Sawan', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Rae Bareli', Decimal('3.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Saint-Denis', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Szkesfehrvr', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4.0, 'Uijongbu', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 5.0, 'Trshavn', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 1.0, 'Lublin', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 1.0, 'Sunnyvale', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 2.0, 'Kamarhati', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 2.0, 'Rae Bareli', Decimal('2.99')),
#  ('ARMY FLINTSTONES', 2.0, 'Sterling Heights', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 3.0, 'Boa Vista', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 3.0, 'Lengshuijiang', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 3.0, 'Po', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 3.0, 'Yamuna Nagar', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 3.0, 'Yuzhou', Decimal('4.99')),
#  ('ARMY FLINTSTONES', 4.0, 'Aden', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 4.0, 'Cavite', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 4.0, 'Jodhpur', Decimal('2.99')),
#  ('ARMY FLINTSTONES', 4.0, 'Kurashiki', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 4.0, 'Pune', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 4.0, 'Skikda', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 1.0, 'Ogbomosho', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 1.0, 'Rajkot', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 2.0, 'Hamilton', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 2.0, 'Myingyan', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 2.0, 'Valencia', Decimal('3.99')),
#  ('ARTIST COLDBLOODED', 3.0, 'Funafuti', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 3.0, 'Jastrzebie-Zdrj', Decimal('3.99')),
#  ('ARTIST COLDBLOODED', 3.0, 'Mosul', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 3.0, 'Tafuna', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 4.0, 'Ashdod', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 4.0, 'Bijapur', Decimal('5.99')),
#  ('ARTIST COLDBLOODED', 4.0, 'Duisburg', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 4.0, 'Juazeiro do Norte', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 4.0, 'Lubumbashi', Decimal('5.99')),
#  ('ARTIST COLDBLOODED', 4.0, 'Nha Trang', Decimal('4.99')),
#  ('ARTIST COLDBLOODED', 4.0, 'Zaria', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 1.0, 'Sivas', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 1.0, 's-Hertogenbosch', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 2.0, 'Balurghat', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 2.0, 'Beni-Mellal', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 2.0, 'Fuzhou', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 3.0, 'Brockton', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3.0, 'Caracas', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3.0, 'Emmen', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3.0, 'Jodhpur', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3.0, 'Sambhal', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3.0, 'Sogamoso', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3.0, 'Tabriz', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3.0, 'Tanauan', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 3.0, 'al-Manama', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 3.0, 'guas Lindas de Gois', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4.0, 'Abu Dhabi', Decimal('3.99')),
#  ('ATLANTIS CAUSE', 4.0, 'Ashgabat', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4.0, 'Deba Habe', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 4.0, 'Duisburg', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4.0, 'Jining', Decimal('3.99')),
#  ('ATLANTIS CAUSE', 4.0, 'Klerksdorp', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4.0, 'Pontianak', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4.0, 'Pudukkottai', Decimal('3.99')),
#  ('ATLANTIS CAUSE', 4.0, 'Xiangfan', Decimal('3.99')),
#  ('ATTACKS HATE', 2.0, 'Sasebo', Decimal('4.99')),
#  ('ATTACKS HATE', 2.0, 'Yangor', Decimal('7.99')),
#  ('ATTACKS HATE', 3.0, 'Aden', Decimal('7.99')),
#  ('ATTACKS HATE', 3.0, 'Antofagasta', Decimal('8.99')),
#  ('ATTACKS HATE', 3.0, 'Banjul', Decimal('8.99')),
#  ('ATTACKS HATE', 3.0, 'Ife', Decimal('4.99')),
#  ('ATTACKS HATE', 3.0, 'Munger (Monghyr)', Decimal('4.99')),
#  ('ATTACKS HATE', 3.0, 'Owo', Decimal('5.99')),
#  ('ATTACKS HATE', 4.0, 'Ashdod', Decimal('5.99')),
#  ('ATTACKS HATE', 4.0, 'Bern', Decimal('4.99')),
#  ('ATTACKS HATE', 4.0, 'Carmen', Decimal('4.99')),
#  ('ATTACKS HATE', 4.0, 'Ipoh', Decimal('4.99')),
#  ('ATTACKS HATE', 4.0, 'Matsue', Decimal('5.99')),
#  ('ATTACKS HATE', 4.0, 'Sumy', Decimal('8.99')),
#  ('ATTACKS HATE', 4.0, 'Tangail', Decimal('5.99')),
#  ('ATTACKS HATE', 4.0, 'Ueda', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 1.0, 'Sincelejo', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 2.0, 'Ezhou', Decimal('7.99')),
#  ('ATTRACTION NEWTON', 2.0, 'Lengshuijiang', Decimal('6.99')),
#  ('ATTRACTION NEWTON', 2.0, 'Nagaon', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 2.0, 'Portoviejo', Decimal('8.99')),
#  ('ATTRACTION NEWTON', 2.0, 'Tete', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3.0, 'Changzhou', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3.0, 'Jakarta', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3.0, 'Kimberley', Decimal('8.99')),
#  ('ATTRACTION NEWTON', 3.0, 'Mit Ghamr', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3.0, 'Monywa', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3.0, 'Mukateve', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3.0, 'Patiala', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3.0, 'Salzburg', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3.0, 'Southend-on-Sea', Decimal('6.99')),
#  ('ATTRACTION NEWTON', 3.0, 'Zapopan', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4.0, 'Akishima', Decimal('7.99')),
#  ('ATTRACTION NEWTON', 4.0, 'Amroha', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4.0, 'Batna', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4.0, 'Fontana', Decimal('5.99')),
#  ('ATTRACTION NEWTON', 4.0, 'Maikop', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4.0, 'Maracabo', Decimal('8.99')),
#  ('ATTRACTION NEWTON', 4.0, 'Tongliao', Decimal('5.99')),
#  ('ATTRACTION NEWTON', 4.0, 'Zeleznogorsk', Decimal('7.99')),
#  ('AUTUMN CROW', 1.0, 'Ashgabat', Decimal('9.99')),
#  ('AUTUMN CROW', 2.0, 'Iwakuni', Decimal('6.99')),
#  ('AUTUMN CROW', 2.0, 'Stockport', Decimal('10.99')),
#  ('AUTUMN CROW', 3.0, 'Basel', Decimal('9.99')),
#  ('AUTUMN CROW', 3.0, 'Blumenau', Decimal('9.99')),
#  ('AUTUMN CROW', 3.0, 'Touliu', Decimal('5.99')),
#  ('AUTUMN CROW', 4.0, 'Aparecida de Goinia', Decimal('4.99')),
#  ('AUTUMN CROW', 4.0, 'Dallas', Decimal('4.99')),
#  ('AUTUMN CROW', 4.0, 'Fontana', Decimal('9.99')),
#  ('AUTUMN CROW', 4.0, 'Sincelejo', Decimal('4.99')),
#  ('AUTUMN CROW', 4.0, 'Tanshui', Decimal('5.99')),
#  ('BABY HALL', 1.0, 'Novoterkassk', Decimal('4.99')),
#  ('BABY HALL', 2.0, 'Memphis', Decimal('5.99')),
#  ('BABY HALL', 3.0, 'Lilongwe', Decimal('4.99')),
#  ('BABY HALL', 3.0, 'Osmaniye', Decimal('4.99')),
#  ('BABY HALL', 3.0, 'San Juan Bautista Tuxtepec', Decimal('4.99')),
#  ('BABY HALL', 4.0, 'Ilorin', Decimal('6.99')),
#  ('BABY HALL', 4.0, 'Lincoln', Decimal('4.99')),
#  ('BABY HALL', 4.0, 'Surakarta', Decimal('7.99')),
#  ('BACKLASH UNDEFEATED', 1.0, 'Kaliningrad', Decimal('5.99')),
#  ('BACKLASH UNDEFEATED', 1.0, 'Kamyin', Decimal('4.99')),
#  ('BACKLASH UNDEFEATED', 1.0, 'Maring', Decimal('6.99')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Bellevue', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Cuauhtmoc', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Jedda', Decimal('4.99')),
#  ('BACKLASH UNDEFEATED', 2.0, 'Springs', Decimal('4.99')),
#  ('BACKLASH UNDEFEATED', 3.0, 'Blumenau', Decimal('10.99')),
#  ('BACKLASH UNDEFEATED', 3.0, 'Etawah', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 3.0, 'Kursk', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 3.0, 'London', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Elista', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Escobar', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Loja', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Omdurman', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Pontianak', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Tarlac', Decimal('7.99')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Uijongbu', Decimal('5.99')),
#  ('BACKLASH UNDEFEATED', 4.0, 'Uttarpara-Kotrung', Decimal('9.99')),
#  ('BADMAN DAWN', 2.0, 'Huixquilucan', Decimal('2.99')),
#  ('BADMAN DAWN', 2.0, 'Rizhao', Decimal('2.99')),
#  ('BADMAN DAWN', 2.0, 'Tanza', Decimal('5.99')),
#  ('BADMAN DAWN', 2.0, 'Tieli', Decimal('4.99')),
#  ('BADMAN DAWN', 3.0, 'Alvorada', Decimal('2.99')),
#  ('BADMAN DAWN', 3.0, 'Fukuyama', Decimal('2.99')),
#  ('BADMAN DAWN', 3.0, 'Hami', Decimal('5.99')),
#  ('BADMAN DAWN', 3.0, 'Najafabad', Decimal('2.99')),
#  ('BADMAN DAWN', 3.0, 'Simferopol', Decimal('3.99')),
#  ('BADMAN DAWN', 3.0, 'Soshanguve', Decimal('2.99')),
#  ('BADMAN DAWN', 4.0, 'Abha', Decimal('2.99')),
#  ('BADMAN DAWN', 4.0, 'Balikesir', Decimal('2.99')),
#  ('BADMAN DAWN', 4.0, 'Beira', Decimal('4.99')),
#  ('BADMAN DAWN', 4.0, 'Citt del Vaticano', Decimal('3.99')),
#  ('BADMAN DAWN', 4.0, 'Oyo', Decimal('2.99')),
#  ('BADMAN DAWN', 4.0, 'Ozamis', Decimal('2.99')),
#  ('BADMAN DAWN', 4.0, 'Pak Kret', Decimal('6.98')),
#  ('BADMAN DAWN', 4.0, 'Serpuhov', Decimal('2.99')),
#  ('BADMAN DAWN', 4.0, 'Siliguri (Shiliguri)', Decimal('2.99')),
#  ('BADMAN DAWN', 4.0, 'Zaoyang', Decimal('3.99')),
#  ('BAKED CLEOPATRA', 1.0, 'Okayama', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 2.0, 'Tarsus', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 3.0, 'Garden Grove', Decimal('5.99')),
#  ('BAKED CLEOPATRA', 3.0, 'Hiroshima', Decimal('3.99')),
#  ('BAKED CLEOPATRA', 3.0, 'Madiun', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 3.0, 'Santa Rosa', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 4.0, 'Acua', Decimal('4.99')),
#  ('BAKED CLEOPATRA', 4.0, 'Bergamo', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 4.0, 'Gandhinagar', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 4.0, 'Hodeida', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 4.0, 'Ourense (Orense)', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 4.0, 'Phnom Penh', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 4.0, 'San Miguel de Tucumn', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 4.0, 'Valencia', Decimal('7.99')),
#  ('BAKED CLEOPATRA', 4.0, 'Vila Velha', Decimal('7.99')),
#  ('BAKED CLEOPATRA', 5.0, 'Haiphong', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 1.0, 'Witten', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 2.0, 'Botosani', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 2.0, 'Datong', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 2.0, 'Pak Kret', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 2.0, 'Plock', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 2.0, 'Vitria de Santo Anto', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3.0, 'Allende', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3.0, 'Araatuba', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3.0, 'Binzhou', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 3.0, 'Cianjur', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3.0, 'Fuyu', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 3.0, 'Livorno', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 3.0, 'Salzburg', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 3.0, 'Udaipur', Decimal('5.99')),
#  ('BALLOON HOMEWARD', 3.0, 'Zaoyang', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 4.0, 'Beira', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 4.0, 'Beni-Mellal', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 4.0, 'Bucuresti', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 4.0, 'Junan', Decimal('4.99')),
#  ('BALLOON HOMEWARD', 4.0, 'Roanoke', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 4.0, 'Yantai', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 4.0, 'Yerevan', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 4.0, 'Yinchuan', Decimal('6.99')),
#  ('BALLROOM MOCKINGBIRD', 1.0, 'Valparai', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 2.0, 'Compton', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 3.0, 'Cam Ranh', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 3.0, 'Omiya', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 3.0, 'Tychy', Decimal('1.99')),
#  ('BALLROOM MOCKINGBIRD', 4.0, 'Effon-Alaiye', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 4.0, 'Malm', Decimal('2.99')),
#  ('BALLROOM MOCKINGBIRD', 4.0, 'Tarsus', Decimal('0.99')),
#  ('BANG KWAI', 2.0, 'Torren', Decimal('3.99')),
#  ('BANG KWAI', 3.0, 'Coatzacoalcos', Decimal('3.99')),
#  ('BANG KWAI', 3.0, 'Pontianak', Decimal('2.99')),
#  ('BANG KWAI', 4.0, 'Boa Vista', Decimal('2.99')),
#  ('BANG KWAI', 4.0, 'Nagaon', Decimal('2.99')),
#  ('BANG KWAI', 4.0, 'Shikarpur', Decimal('2.99')),
#  ('BANG KWAI', 5.0, 'Taizz', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 1.0, 'Shubra al-Khayma', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 1.0, 'Tonghae', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 2.0, 'Cabuyao', Decimal('1.99')),
#  ('BANGER PINOCCHIO', 2.0, 'Cavite', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 2.0, 'Munger (Monghyr)', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 2.0, 'Novoterkassk', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 2.0, 'Siliguri (Shiliguri)', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 3.0, 'Abha', Decimal('1.99')),
#  ('BANGER PINOCCHIO', 3.0, 'Binzhou', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 3.0, 'Emeishan', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 3.0, 'Kaduna', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 3.0, 'Ocumare del Tuy', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 3.0, 'Simferopol', Decimal('4.99')),
#  ('BANGER PINOCCHIO', 3.0, 'Tama', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4.0, 'Almirante Brown', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4.0, 'Bamenda', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 4.0, 'Jakarta', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4.0, 'Jinchang', Decimal('4.99')),
#  ('BANGER PINOCCHIO', 4.0, 'Katihar', Decimal('3.99')),
#  ('BANGER PINOCCHIO', 4.0, 'Tychy', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 4.0, 'Vancouver', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4.0, 'Vicente Lpez', Decimal('0.99')),
#  ('BARBARELLA STREETCAR', 1.0, 'Alvorada', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 1.0, 'Bucuresti', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 1.0, 'Kamakura', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2.0, 'Ashdod', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2.0, 'Cuernavaca', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2.0, 'Ezeiza', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2.0, 'Graz', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2.0, 'Uruapan', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 3.0, 'Abha', Decimal('4.99')),
#  ('BARBARELLA STREETCAR', 3.0, 'Bellevue', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 3.0, 'Gandhinagar', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 3.0, 'Huixquilucan', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 3.0, 'Ikerre', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 3.0, 'Maring', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 3.0, 'Richmond Hill', Decimal('4.99')),
#  ('BARBARELLA STREETCAR', 3.0, 'Sal', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 3.0, 'Yuncheng', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 4.0, 'Hubli-Dharwad', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 4.0, 'Meixian', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 4.0, 'Miraj', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 4.0, 'Moscow', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 4.0, 'Niznekamsk', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 4.0, 'Qomsheh', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 4.0, 'South Hill', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 4.0, 'Tabriz', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 1.0, 'Juazeiro do Norte', Decimal('6.99')),
#  ('BAREFOOT MANCHURIAN', 2.0, 'Halifax', Decimal('4.99')),
#  ('BAREFOOT MANCHURIAN', 2.0, 'Jelets', Decimal('3.99')),
#  ('BAREFOOT MANCHURIAN', 2.0, 'Madiun', Decimal('3.99')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Basel', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Fukuyama', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Halisahar', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Kuwana', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Pontianak', Decimal('5.99')),
#  ('BAREFOOT MANCHURIAN', 3.0, 'Torren', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Adoni', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Guadalajara', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Haiphong', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Jastrzebie-Zdrj', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Kitwe', Decimal('4.99')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Le Mans', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'Ljubertsy', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4.0, 'al-Manama', Decimal('2.99')),
#  ('BASIC EASY', 1.0, 'Tianjin', Decimal('2.99')),
#  ('BASIC EASY', 2.0, 'Shimoga', Decimal('2.99')),
#  ('BASIC EASY', 2.0, 'Sincelejo', Decimal('2.99')),
#  ('BASIC EASY', 3.0, 'Akishima', Decimal('3.99')),
#  ('BASIC EASY', 3.0, 'Bayugan', Decimal('5.99')),
#  ('BASIC EASY', 3.0, 'Escobar', Decimal('7.99')),
#  ('BASIC EASY', 3.0, 'Jurez', Decimal('3.99')),
#  ('BASIC EASY', 3.0, 'Konotop', Decimal('2.99')),
#  ('BASIC EASY', 3.0, 'Santiago de Compostela', Decimal('2.99')),
#  ('BASIC EASY', 3.0, 'Vancouver', Decimal('5.99')),
#  ('BASIC EASY', 3.0, 'Ziguinchor', Decimal('2.99')),
#  ('BASIC EASY', 4.0, 'Batman', Decimal('3.99')),
#  ('BASIC EASY', 4.0, 'Haining', Decimal('2.99')),
#  ('BASIC EASY', 4.0, 'Imus', Decimal('2.99')),
#  ('BASIC EASY', 4.0, 'Lubumbashi', Decimal('6.99')),
#  ('BASIC EASY', 4.0, 'Novi Sad', Decimal('2.99')),
#  ('BASIC EASY', 4.0, 'Pjatigorsk', Decimal('2.99')),
#  ('BASIC EASY', 4.0, 'Robamba', Decimal('3.99')),
#  ('BASIC EASY', 4.0, 'Santa Rosa', Decimal('7.99')),
#  ('BASIC EASY', 4.0, 'Simferopol', Decimal('6.99')),
#  ('BASIC EASY', 5.0, 'Laohekou', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 1.0, 'Almirante Brown', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 1.0, 'Katihar', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 2.0, 'Cuautla', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 2.0, 'Kilis', Decimal('4.99')),
#  ('BEACH HEARTBREAKERS', 2.0, 'Novoterkassk', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Bijapur', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Caracas', Decimal('4.99')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Crdoba', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Hsichuh', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Quilmes', Decimal('3.99')),
#  ('BEACH HEARTBREAKERS', 3.0, 'Sterling Heights', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Kingstown', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Lungtan', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Mysore', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Pathankot', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Ruse', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 4.0, 'Xiangtan', Decimal('2.99')),
#  ('BEAR GRACELAND', 1.0, 'Pingxiang', Decimal('3.99')),
#  ('BEAR GRACELAND', 1.0, 'Tabuk', Decimal('6.99')),
#  ('BEAR GRACELAND', 1.0, 'Uijongbu', Decimal('2.99')),
#  ('BEAR GRACELAND', 2.0, 'Bchar', Decimal('2.99')),
#  ('BEAR GRACELAND', 2.0, 'Bhopal', Decimal('2.99')),
#  ('BEAR GRACELAND', 2.0, 'Nakhon Sawan', Decimal('5.99')),
#  ('BEAR GRACELAND', 2.0, 'South Hill', Decimal('2.99')),
#  ('BEAR GRACELAND', 3.0, 'Angra dos Reis', Decimal('7.99')),
#  ('BEAR GRACELAND', 3.0, 'Juazeiro do Norte', Decimal('7.99')),
#  ('BEAR GRACELAND', 3.0, 'Olomouc', Decimal('3.99')),
#  ('BEAR GRACELAND', 3.0, 'Pune', Decimal('5.99')),
#  ('BEAR GRACELAND', 3.0, 'Rio Claro', Decimal('4.99')),
#  ('BEAR GRACELAND', 3.0, 'Robamba', Decimal('6.99')),
#  ('BEAR GRACELAND', 3.0, 'Tiefa', Decimal('3.99')),
#  ('BEAR GRACELAND', 4.0, 'Addis Abeba', Decimal('2.99')),
#  ('BEAR GRACELAND', 4.0, 'Ahmadnagar', Decimal('6.99')),
#  ('BEAR GRACELAND', 4.0, 'Bhilwara', Decimal('2.99')),
#  ('BEAR GRACELAND', 4.0, 'Czestochowa', Decimal('4.99')),
#  ('BEAR GRACELAND', 4.0, 'Lapu-Lapu', Decimal('4.99')),
#  ('BEAR GRACELAND', 4.0, 'Liaocheng', Decimal('7.99')),
#  ('BEAR GRACELAND', 4.0, 'Mardan', Decimal('2.99')),
#  ('BEAR GRACELAND', 4.0, 'Shenzhen', Decimal('2.99')),
#  ('BEAST HUNCHBACK', 1.0, 'Jinzhou', Decimal('6.99')),
#  ('BEAST HUNCHBACK', 2.0, 'Faaa', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 2.0, 'Nanyang', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 3.0, 'Duisburg', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 3.0, 'Omiya', Decimal('10.99')),
#  ('BEAST HUNCHBACK', 3.0, 'Sincelejo', Decimal('8.99')),
#  ('BEAST HUNCHBACK', 4.0, 'Chandrapur', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 4.0, 'Chiayi', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 4.0, 'Guadalajara', Decimal('10.99')),
#  ('BEAST HUNCHBACK', 4.0, 'Kolpino', Decimal('7.99')),
#  ('BEAST HUNCHBACK', 4.0, 'Zaoyang', Decimal('5.99')),
#  ('BEAUTY GREASE', 1.0, 'Denizli', Decimal('6.99')),
#  ('BEAUTY GREASE', 2.0, 'Barcelona', Decimal('4.99')),
#  ('BEAUTY GREASE', 2.0, 'Daugavpils', Decimal('8.99')),
#  ('BEAUTY GREASE', 2.0, 'Huixquilucan', Decimal('4.99')),
#  ('BEAUTY GREASE', 3.0, 'Davao', Decimal('4.99')),
#  ('BEAUTY GREASE', 3.0, 'Firozabad', Decimal('4.99')),
#  ('BEAUTY GREASE', 3.0, 'Jaffna', Decimal('4.99')),
#  ('BEAUTY GREASE', 3.0, 'Kursk', Decimal('8.99')),
#  ('BEAUTY GREASE', 3.0, 'Lancaster', Decimal('8.99')),
#  ('BEAUTY GREASE', 3.0, 'Mwene-Ditu', Decimal('5.99')),
#  ('BEAUTY GREASE', 3.0, 'Richmond Hill', Decimal('4.99')),
#  ('BEAUTY GREASE', 3.0, 'Ziguinchor', Decimal('4.99')),
#  ('BEAUTY GREASE', 4.0, 'Acua', Decimal('4.99')),
#  ('BEAUTY GREASE', 4.0, 'Arlington', Decimal('4.99')),
#  ('BEAUTY GREASE', 4.0, 'Bhopal', Decimal('4.99')),
#  ('BEAUTY GREASE', 4.0, 'Dhule (Dhulia)', Decimal('7.99')),
#  ('BEAUTY GREASE', 4.0, 'Hsichuh', Decimal('4.99')),
#  ('BEAUTY GREASE', 4.0, 'Kamarhati', Decimal('6.99')),
#  ('BEAUTY GREASE', 4.0, 'Nezahualcyotl', Decimal('6.99')),
#  ('BEAUTY GREASE', 4.0, 'Omdurman', Decimal('4.99')),
#  ('BEAUTY GREASE', 4.0, 'Syktyvkar', Decimal('5.99')),
#  ('BEAUTY GREASE', 4.0, 'Zhezqazghan', Decimal('4.99')),
#  ('BED HIGHBALL', 3.0, 'Bhimavaram', Decimal('3.99')),
#  ('BED HIGHBALL', 3.0, 'Liaocheng', Decimal('2.99')),
#  ('BED HIGHBALL', 3.0, 'San Miguel de Tucumn', Decimal('2.99')),
#  ('BED HIGHBALL', 4.0, 'Iligan', Decimal('2.99')),
#  ('BED HIGHBALL', 4.0, 'Kursk', Decimal('5.99')),
#  ('BED HIGHBALL', 4.0, 'Santo Andr', Decimal('5.99')),
#  ('BEDAZZLED MARRIED', 1.0, 'Angra dos Reis', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', 2.0, 'Balurghat', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 2.0, 'Myingyan', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 3.0, 'Baybay', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 3.0, 'Duisburg', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 3.0, 'Le Mans', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', 3.0, 'Naju', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 3.0, 'San Felipe de Puerto Plata', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 4.0, 'Binzhou', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', 4.0, 'Naju', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 4.0, 'Serpuhov', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 4.0, 'Shanwei', Decimal('1.99')),
#  ...]

# %% [markdown]
# # Conclusion

# %% [markdown]
# - We were able to show that a start schema is easier to understand
# - Evidence that is more performant

# %%
# !PGPASSWORD=student pg_dump -h 127.0.0.1 -U student pagila > Data/pagila-star.sql
